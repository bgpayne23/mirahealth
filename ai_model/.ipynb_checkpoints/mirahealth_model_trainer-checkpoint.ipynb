# %%
#Import Libraries
import pandas as pd
import requests
import io

# %%
# Downloading the csv file from the GitHub account
url = "https://raw.githubusercontent.com/bgpayne23/mirahealth/main/datasets/mira_data_one_hot.csv" # Make sure the url is the raw version of the file on GitHub
download = requests.get(url).content
# Reading the downloaded content and turning it into a pandas dataframe
df = pd.read_csv(io.StringIO(download.decode('utf-8')))
# Printing out the first 5 rows of the dataframe
df.drop('Unnamed: 0', inplace=True, axis=1)
df
# Out:
#       obgyn_AvgPatientTime  obgyn_NumOfPatients  obgyn_QualityRisk  \
# 0                       21                   16                  0
# 1                       11                   30                  1
# 2                       13                   18                  1
# 3                       13                   21                  1
# 4                       14                   26                  0
# ...                    ...                  ...                ...
# 2257                    18                   27                  0
# 2258                    18                   23                  0
# 2259                    11                   30                  1
# 2260                    21                   16                  0
# 2261                     9                   22                  1
#
#       obgyn_TotalHours  obgyn_BurnoutRisk  Age  SystolicBP  DiastolicBP    BS  \
# 0                  336                  0   18         120           90   6.1
# ...

# %%
#split dataset in features and target variable
feature_cols = df.columns.values.tolist()
feature_cols.remove('HDP')
X = df[feature_cols] # Features
y = df.HDP # Target variable

# %%
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=16)

# %%
# import the class
from sklearn.linear_model import LogisticRegression
# instantiate the model (using the default parameters)
logreg = LogisticRegression()
# fit the model with data
logreg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nv/tch67c355nb6y6qgyvjc30p40000gn/T/ipykernel_66651/2497514752.py in <module>
#       2 from sklearn.linear_model import LogisticRegression
#       3 # instantiate the model (using the default parameters)
# ----> 4 logreg = LogisticRegression(max_iter)
#       5 # fit the model with data
#       6 logreg.fit(X_train, y_train)
#
# NameError: name 'max_iter' is not defined

# %%
#Score the Accuracy of the model
from sklearn.metrics import accuracy_score
y_pred = logreg.predict(X_test)
score =accuracy_score(y_test,y_pred)
print('Test Accuracy Score: ', score)
# Out:
# Test Accuracy Score:  0.8869257950530035
